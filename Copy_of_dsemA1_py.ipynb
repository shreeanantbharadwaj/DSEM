# %% [markdown]
# <a href="https://colab.research.google.com/github/shreeanantbharadwaj/DSEM/blob/main/Copy_of_dsemA1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Abstract
# The Medicare Durable Medical Equipment, Devices & Supplies by Geography and Service dataset provides comprehensive insights into the utilization, financial transactions, and service patterns related to durable medical equipment and supplies under Medicare. The dataset is organized by geography, Healthcare Common Procedure Coding System (HCPCS) code, and supplier rental indicator. This valuable resource facilitates a detailed exploration of healthcare service delivery, usage trends, and associated financial aspects.In this exploratory analysis, statistical methods such as p-value and t-statistics, along with visualization techniques including histograms, Q-Q plots, scatter plots, and box plots from Python's Matplotlib and Seaborn libraries, are employed. The primary objective is to assess the quality of the dataset and discern the significance of various features. By leveraging these analytical tools, the notebook aims to answer key questions about the dataset, unraveling patterns and relationships that contribute to a comprehensive understanding of the Medicare Durable Medical Equipment landscape.These methods are used to answer the folowing questions: • Which independent variables are useful to predict a target (dependent variable?
#
# • Which independent variables have missing data? How much?
#
# • Do the training and test sets have the same data?
#
# • In the predictor variables independent of all the other predictor variables?
#
# • Which predictor variables are the most important?
#
# • Do the ranges of the predictor variables make sense?
#
# • What are the distributions of the predictor variables?

# %% [markdown]
# # Dataset
# The dataset consist of :
# 1. 8 factors that might be useful to predict the Tot_Rfrg_Prvdrs,Tot_Suplrs,
#  Tot_Suplr_Benes,Tot_Suplr_Clms,Tot_Suplr_Srvcs,Avg_Suplr_Sbmtd_Chrg,Avg_Suplr_Mdcr_Alowd_Amt,Avg_Suplr_Mdcr_Pymt_Amt,Avg_Suplr_Mdcr_Stdzd_Amt
# 2.  Avg_Suplr_Mdcr_Pymt_Amt: Average Medicare payment amount by supplier - The
#     dependent variable
# 3. There are total 7083 observations

# %%
pip install eli5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.2/216.2 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for eli5: filename=eli5-0.13.0-py2.py3-none-any.whl size=107717 sha256=2ddce40ed514e36ea74c7cfc19303782383d8104b04212592ba2e5d793be7928
#   Stored in directory: /root/.cache/pip/wheels/b8/58/ef/2cf4c306898c2338d51540e0922c8e0d6028e07007085c0004
# Successfully built eli5
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from matplotlib import pyplot
np.random.seed(0)
H17 = pd.read_csv('/content/healthsupplier_2017_deleted.csv')

# %%
H17.dtypes
# Out:
# Rfrg_Prvdr_Geo_Lvl           object
# Rfrg_Prvdr_Geo_Cd           float64
# Rfrg_Prvdr_Geo_Desc          object
# BETOS_Lvl                    object
# BETOS_Cd                     object
# BETOS_Desc                   object
# HCPCS_Cd                     object
# HCPCS_Desc                   object
# Suplr_Rentl_Ind              object
# Tot_Rfrg_Prvdrs             float64
# Tot_Suplrs                  float64
# Tot_Suplr_Benes             float64
# Tot_Suplr_Clms              float64
# Tot_Suplr_Srvcs             float64
# Avg_Suplr_Sbmtd_Chrg        float64
# Avg_Suplr_Mdcr_Alowd_Amt    float64
# Avg_Suplr_Mdcr_Pymt_Amt     float64
# Avg_Suplr_Mdcr_Stdzd_Amt    float64
# dtype: object

# %% [markdown]
# # Dataset
# Rfrg_Prvdr_Geo_Lvl: Geographic level of the referring provider.(Categorical)
#
# Rfrg_Prvdr_Geo_Cd: Geographic code of the referring provider.(Numerical)
#
# Rfrg_Prvdr_Geo_Desc: Description of the geographic region of the referring provider.(Categorical)
#
# BETOS_Lvl: Level of Healthcare Common Procedure Coding System (HCPCS) based on BETOS.(Categorical)
#
# BETOS_Cd: BETOS code.(Categorical)
#
# BETOS_Desc: Description of BETOS.(Categorical)
#
# HCPCS_Cd: HCPCS code.(Categorical)
#
# HCPCS_Desc: Description of HCPCS.(Categorical)
#
# Suplr_Rentl_Ind: Indicator for supplier rental.(Categorical
# )
# Tot_Rfrg_Prvdrs: Total number of referring providers.(Numerical)
#
# Tot_Suplrs: Total number of suppliers.(Numerical)
#
# Tot_Suplr_Benes: Total number of supplier beneficiaries.(Numerical)
#
# Tot_Suplr_Clms: Total number of supplier claims.(Numerical)
#
# Tot_Suplr_Srvcs: Total number of supplier services.(Numerical)
#
# Avg_Suplr_Sbmtd_Chrg: Average submitted charges by supplier.(Numerical
# )
# Avg_Suplr_Mdcr_Alowd_Amt: Average Medicare allowed amount by supplier.(Numerical)
#
# Avg_Suplr_Mdcr_Pymt_Amt: Average Medicare payment amount by supplier.(Numerical)
#
# Avg_Suplr_Mdcr_Stdzd_Amt: Average standardized Medicare payment amount by supplier.(Numerical)

# %%
H17.isnull().sum()
# Out:
# Rfrg_Prvdr_Geo_Lvl          2085
# Rfrg_Prvdr_Geo_Cd           3785
# Rfrg_Prvdr_Geo_Desc         2085
# BETOS_Lvl                   2085
# BETOS_Cd                    2085
# BETOS_Desc                  2085
# HCPCS_Cd                    2085
# HCPCS_Desc                  2085
# Suplr_Rentl_Ind             2085
# Tot_Rfrg_Prvdrs             2085
# Tot_Suplrs                  2085
# Tot_Suplr_Benes             2570
# Tot_Suplr_Clms              2085
# Tot_Suplr_Srvcs             2085
# Avg_Suplr_Sbmtd_Chrg        2085
# Avg_Suplr_Mdcr_Alowd_Amt    2085
# Avg_Suplr_Mdcr_Pymt_Amt     2085
# Avg_Suplr_Mdcr_Stdzd_Amt    2085
# dtype: int64

# %%
dropped_data = H17.dropna()

# %%
dropped_data.isnull().sum()
# Out:
# Rfrg_Prvdr_Geo_Lvl          0
# Rfrg_Prvdr_Geo_Cd           0
# Rfrg_Prvdr_Geo_Desc         0
# BETOS_Lvl                   0
# BETOS_Cd                    0
# BETOS_Desc                  0
# HCPCS_Cd                    0
# HCPCS_Desc                  0
# Suplr_Rentl_Ind             0
# Tot_Rfrg_Prvdrs             0
# Tot_Suplrs                  0
# Tot_Suplr_Benes             0
# Tot_Suplr_Clms              0
# Tot_Suplr_Srvcs             0
# Avg_Suplr_Sbmtd_Chrg        0
# Avg_Suplr_Mdcr_Alowd_Amt    0
# Avg_Suplr_Mdcr_Pymt_Amt     0
# Avg_Suplr_Mdcr_Stdzd_Amt    0
# dtype: int64

# %% [markdown]
# ***Question 2:***Are there missing values?
#
# Answer: No

# %% [markdown]
# ***Question 3:*** Distributions

# %%
dropped_data.dtypes
# Out:
# Rfrg_Prvdr_Geo_Lvl           object
# Rfrg_Prvdr_Geo_Cd           float64
# Rfrg_Prvdr_Geo_Desc          object
# BETOS_Lvl                    object
# BETOS_Cd                     object
# BETOS_Desc                   object
# HCPCS_Cd                     object
# HCPCS_Desc                   object
# Suplr_Rentl_Ind              object
# Tot_Rfrg_Prvdrs             float64
# Tot_Suplrs                  float64
# Tot_Suplr_Benes             float64
# Tot_Suplr_Clms              float64
# Tot_Suplr_Srvcs             float64
# Avg_Suplr_Sbmtd_Chrg        float64
# Avg_Suplr_Mdcr_Alowd_Amt    float64
# Avg_Suplr_Mdcr_Pymt_Amt     float64
# Avg_Suplr_Mdcr_Stdzd_Amt    float64
# dtype: object

# %%
# checking the distribution of independent variables
from statsmodels.graphics.gofplots import qqplot

data_norm = dropped_data[['Tot_Rfrg_Prvdrs', 'Tot_Suplrs','Tot_Suplr_Clms', 'Tot_Suplr_Srvcs', 'Avg_Suplr_Sbmtd_Chrg','Avg_Suplr_Mdcr_Alowd_Amt', 'Avg_Suplr_Mdcr_Pymt_Amt','Avg_Suplr_Mdcr_Stdzd_Amt']]
for c in data_norm.columns[:]:
    plt.figure(figsize=(8, 5))
    fig = qqplot(data_norm[c], line="45", fit="True")
    plt.xticks(fontsize=13)
    plt.yticks(fontsize=13)
    plt.xlabel("Theoretical quantiles", fontsize=15)
    plt.ylabel("Sample quantiles", fontsize=15)
    plt.title("Q-Q plot of {}".format(c), fontsize=16)
    plt.grid(True)
    plt.show()

# %% [markdown]
# After looking at graphs we cocnlude that the above datset is not suitable for distribution so we have to normalize all the columns

# %%
from scipy import stats
from scipy.stats import boxcox
import pandas as pd

import pandas as pd

numeric_columns = dropped_data.select_dtypes(include=['number'])

numeric_data = pd.DataFrame(numeric_columns)


normalized_data = pd.DataFrame()
for column in numeric_data.columns:
    transformed_col = stats.boxcox(numeric_data[column] + 1, lmbda=0.0)
    transformed_col = transformed_col.astype(int)  # Convert to integers
    normalized_data[column] =transformed_col

# %%
from statsmodels.graphics.gofplots import qqplot

data_norm = normalized_data[['Tot_Rfrg_Prvdrs', 'Tot_Suplrs','Tot_Suplr_Clms', 'Tot_Suplr_Srvcs', 'Avg_Suplr_Sbmtd_Chrg','Avg_Suplr_Mdcr_Alowd_Amt', 'Avg_Suplr_Mdcr_Pymt_Amt','Avg_Suplr_Mdcr_Stdzd_Amt']]
for c in data_norm.columns[:]:
    plt.figure(figsize=(8, 5))
    fig = qqplot(data_norm[c], line="45", fit="True")
    plt.xticks(fontsize=13)
    plt.yticks(fontsize=13)
    plt.xlabel("Theoretical quantiles", fontsize=15)
    plt.ylabel("Sample quantiles", fontsize=15)
    plt.title("Q-Q plot of {}".format(c), fontsize=16)
    plt.grid(True)
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming data_norm is your DataFrame
# Replace this with your actual DataFrame name

columns_to_plot = ['Tot_Rfrg_Prvdrs', 'Tot_Suplrs', 'Tot_Suplr_Clms', 'Tot_Suplr_Srvcs',
                   'Avg_Suplr_Sbmtd_Chrg', 'Avg_Suplr_Mdcr_Alowd_Amt', 'Avg_Suplr_Mdcr_Pymt_Amt', 'Avg_Suplr_Mdcr_Stdzd_Amt']

# Create subplots for each column
plt.figure(figsize=(15, 10))

for i, column in enumerate(columns_to_plot, 1):
    plt.subplot(4, 2, i)
    sns.distplot(data_norm[column], kde=True, bins=20, color='blue')
    plt.title(f'Distribution of {column}')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-15-d81a254cd8f2>:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_norm[column], kde=True, bins=20, color='blue')
# <ipython-input-15-d81a254cd8f2>:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# As you can see the data is not normally distributed. It appears to be discrete in the qqplot. On a distplot, the distribution appears to be normal for , 'Tot_Suplr_Clms', 'Tot_Suplr_Srvcs','Avg_Suplr_Sbmtd_Chrg', 'Avg_Suplr_Mdcr_Alowd_Amt', 'Avg_Suplr_Mdcr_Pymt_Amt', 'Avg_Suplr_Mdcr_Stdzd_Amt'.For 'Tot_Suplr_Clms', 'Tot_Suplr_Srvcs' the data is right skewed.And for 'Tot_Rfrg_Prvdrs', 'Tot_Suplrs' the distribution has many fluctuations

# %%
# data_norm.drop(columns = ['Tot_Rfrg_Prvdrs', 'Tot_Suplrs'], axis = 1, inplace=True)
# data_norm

# %%
plt.figure(figsize=(20, 7))
sns.boxplot(data_norm)
# Out:
# <Axes: >

# %% [markdown]
# The length of the box indicates the spread of the middle 50% of the data. A longer box suggests a larger spread, while a shorter box suggests a smaller spread.The whiskers extend from the edges of the box to the minimum and maximum values within a specified distance (usually 1.5 times the IQR). Any data points beyond the whiskers are considered outliers.
# Outliers are individual data points that are significantly higher or lower than the majority of the data. They are represented as individual points beyond the whiskers.The line inside the box represents the median, which is the middle value when the data is sorted in ascending order. It divides the dataset into two halves.Some box plots have notches in the boxes. Notches are used to compare groups; if the notches of two boxes do not overlap, it suggests that the medians may be significantly different.The orientation and length of the box and whiskers can give insights into the skewness and symmetry of the data distribution. For example, if the median is closer to the bottom of the box, the data may be right-skewed.The concentration of data points within the box and around the median provides information about the density of data values. A denser concentration suggests a more uniform distribution.

# %% [markdown]
# # ***Data transforming, Feature creation and Analysis***

# %%
data_norm.corr()
# Out:
#                           Tot_Rfrg_Prvdrs  Tot_Suplrs  Tot_Suplr_Clms  \
# Tot_Rfrg_Prvdrs                  1.000000    0.843873        0.873104
# Tot_Suplrs                       0.843873    1.000000        0.796334
# Tot_Suplr_Clms                   0.873104    0.796334        1.000000
# Tot_Suplr_Srvcs                  0.625971    0.577464        0.804512
# Avg_Suplr_Sbmtd_Chrg            -0.109842   -0.087151       -0.240570
# Avg_Suplr_Mdcr_Alowd_Amt        -0.139437   -0.117243       -0.298717
# Avg_Suplr_Mdcr_Pymt_Amt         -0.142489   -0.124265       -0.302140
# Avg_Suplr_Mdcr_Stdzd_Amt        -0.143834   -0.124257       -0.299565
#
#                           Tot_Suplr_Srvcs  Avg_Suplr_Sbmtd_Chrg  \
# Tot_Rfrg_Prvdrs                  0.625971             -0.109842
# Tot_Suplrs                       0.577464             -0.087151
# Tot_Suplr_Clms                   0.804512             -0.240570
# Tot_Suplr_Srvcs                  1.000000             -0.554825
# ...

# %%
plt.figure(figsize=(20, 7))
sns.heatmap(data_norm.corr(), annot=True, cmap="RdYlGn")
# Out:
# <Axes: >

# %%
sns.pairplot(data_norm)

# %% [markdown]
# ***Types of Co-relation between data***
#
# Correlation matrix and heatmap shows that there is multicollinearity between the independent variables.
# 1. Positive Co-relation -
# When one variable increases the other increases as well.
#
# 2. Negative Co-relation -
# When one variable increases then the other decreases
#
# Highest Co-relation is between (Avg_Supt_Mdcr_Pymt_Amt and Avg_Supplr_Mdcr_Amt) and (Avg_Suplr_Mdcr_Stdzd_Amt and Avg_Supr_Mdcr_Pymt_Amt) with a 0.99 Co-relation.

# %% [markdown]
# ***Identifing predictor significance***

# %%
# Using OLS for finding the p value to check the significant features
import statsmodels.api as sm

model = sm.OLS(
    data_norm["Avg_Suplr_Mdcr_Pymt_Amt"],
    data_norm[
        [
          'Tot_Rfrg_Prvdrs',
          'Tot_Suplrs',
          'Tot_Suplr_Clms',
          'Tot_Suplr_Srvcs',
          'Avg_Suplr_Sbmtd_Chrg',
          'Avg_Suplr_Mdcr_Alowd_Amt',
          'Avg_Suplr_Mdcr_Pymt_Amt',
          'Avg_Suplr_Mdcr_Stdzd_Amt'
        ]
    ],
).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     Avg_Suplr_Mdcr_Pymt_Amt   R-squared (uncentered):                   1.000
# Model:                                 OLS   Adj. R-squared (uncentered):              1.000
# Method:                      Least Squares   F-statistic:                          1.200e+33
# Date:                     Mon, 29 Jan 2024   Prob (F-statistic):                        0.00
# Time:                             21:53:54   Log-Likelihood:                          93679.
# No. Observations:                     2892   AIC:                                 -1.873e+05
# Df Residuals:                         2884   BIC:                                 -1.873e+05
# Df Model:                                8
# Covariance Type:                 nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# The Tot_Rfrg_Prvdrs has the p-value 0.000, which is lesser and hence it is a significant feature.
#
# The Tot_Suplrs has the p-value 0.000, which is lesser and hence it is a significant feature.
#
# The Tot_Suplr_Clms has the p-value 0.019, which is lesser and hence it is a significant feature.
#
# The Tot_Suplr_Srvcs has the p-value 0.160, which is greater and hence it is a non-significant feature.
#
# The Avg_Suplr_Sbmtd_Chrg has the p-value 0.000, which is lesser and hence it is a significant feature.
#
# The Avg_Suplr_Mdcr_Alowd_Amt has the p-value 0.000, which is lesser and hence it is a significant feature.
#
# The Avg_Suplr_Mdcr_Pymt_Amt has the p-value 0.000, which is lesser and hence it is a significant feature.
#
# The Avg_Suplr_Mdcr_Stdzd_Amt has the p-value 0.027, which is lesser and hence it is a significant feature.
#
# This interpretation is based on the convention of considering a p-value less than 0.05 as an indication of statistical significance. If the p-value is less than 0.05, the feature is considered significant; otherwise, it is considered non-significant.

# %% [markdown]
# # ***Building the Model -Train ,Validation and Test split***

# %% [markdown]
# Data scientists try to make models that are robust meaning they will give consistent results that are correct most of the time. Generally we divide the dataset into 70% for training, 20% Testing and 10% for Validation. The model is training using training data. The relations are drawn and patterns are identified so predictions can be made. We use the Validation data to evaluate how well the model does. Based on the result we tune the hyperparameters of the model. This is called Optimization. Then we use the test data to see how well our model is performing.

# %%
from sklearn.model_selection import train_test_split

X = data_norm[
    [
          'Tot_Rfrg_Prvdrs',
          'Tot_Suplrs',
          'Tot_Suplr_Clms',
          'Tot_Suplr_Srvcs',
          'Avg_Suplr_Sbmtd_Chrg',
          'Avg_Suplr_Mdcr_Alowd_Amt',
          'Avg_Suplr_Mdcr_Pymt_Amt',
          'Avg_Suplr_Mdcr_Stdzd_Amt'
    ]
]

y = data_norm["Avg_Suplr_Mdcr_Pymt_Amt"]

# Spliting data into Training 76.5%, Validation set 13.5% and Test set 10%

X_t, X_test, y_t, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(
    X_t, y_t, test_size=0.15, random_state=1
)

# %%
# Looking the data for test, training and validation set
X_test_plot = X_test[
    [
          'Tot_Rfrg_Prvdrs',
          'Tot_Suplrs',
          'Tot_Suplr_Clms',
          'Tot_Suplr_Srvcs',
          'Avg_Suplr_Sbmtd_Chrg',
          'Avg_Suplr_Mdcr_Alowd_Amt',
          'Avg_Suplr_Mdcr_Pymt_Amt',
          'Avg_Suplr_Mdcr_Stdzd_Amt'
    ]
]

X_val_plot = X_val[
    [
          'Tot_Rfrg_Prvdrs',
          'Tot_Suplrs',
          'Tot_Suplr_Clms',
          'Tot_Suplr_Srvcs',
          'Avg_Suplr_Sbmtd_Chrg',
          'Avg_Suplr_Mdcr_Alowd_Amt',
          'Avg_Suplr_Mdcr_Pymt_Amt',
          'Avg_Suplr_Mdcr_Stdzd_Amt'
    ]
]

X_train_plot = X_train[
    [
          'Tot_Rfrg_Prvdrs',
          'Tot_Suplrs',
          'Tot_Suplr_Clms',
          'Tot_Suplr_Srvcs',
          'Avg_Suplr_Sbmtd_Chrg',
          'Avg_Suplr_Mdcr_Alowd_Amt',
          'Avg_Suplr_Mdcr_Pymt_Amt',
          'Avg_Suplr_Mdcr_Stdzd_Amt'
    ]
]
# Plotting the data to see the histogram
for c in X_test_plot.columns[:]:
    plt.figure(figsize=(8, 6))
    plt.hist(X_val_plot[c], bins=20, alpha=0.5, label="validation")
    plt.hist(X_test_plot[c], bins=20, alpha=0.5, label="test")
    plt.hist(X_train_plot[c], bins=20, alpha=0.5, label="train")
    plt.xlabel(c, size=14)
    plt.ylabel("Count", size=14)
    plt.legend(loc="upper right")
    plt.title("{} distribution".format(c))
    plt.show()

# %% [markdown]
# # ***Linear Regression***

# %%
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # ***Making predictions***

# %% [markdown]
# Mean squared Error:- measures the amount of error in statistical model. It calculates the average squared difference between the observed and predicted values. The reason it is squared is so the magnitudes don't cancel out each other.
#
# The coefficient of determination:- shows how correlated one dependent and one independent variable are.
#
# R2 score is used to evaluate the performance of a linear regression model. The value will usually range between 0 and 1. Value of < 0.3 is weak.

# %%
# Make predictions using the training set
y_pred = regr.predict(X_train)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_train, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_train, y_pred))
r2 = r2_score(y_train, y_pred)
print("R^2 score on tarining set =", r2)
# Out:
# Mean squared error: 0.00
# Coefficient of determination: 1.00
# R^2 score on tarining set = 1.0

# %%
# Make predictions using the testing set
y_pred = regr.predict(X_test)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print("R^2 score on test set =", r2)
# Out:
# Mean squared error: 0.00
# Coefficient of determination: 1.00
# R^2 score on test set = 1.0

# %%
# Make predictions using the validation set
y_pred = regr.predict(X_val)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_val, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_val, y_pred))
r2_val = r2_score(y_val, y_pred)
print("R^2 score on validation set =", r2_val)
# Out:
# Mean squared error: 0.00
# Coefficient of determination: 1.00
# R^2 score on validation set = 1.0

# %% [markdown]
# # ***Understanding the important features***

# %%
# Understanding the important features
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(regr, random_state=1).fit(X_test, y_test)
eli5.show_weights(perm, feature_names=X_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 2.0015
#
#                     &plusmn; 0.1939
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Avg_Suplr_Mdcr_Pymt_Amt
# ...

# %% [markdown]
# ***Question 4:***
#
# Which independent variables are useful to predict a target (dependent variable)?
#
# A: Below is the rank of the dependent variables
#
# Avg_Suplr_Mdcr_Stdzd_Amount
# Avg_Suplr_Mdcr_Alowd_Amt
# Avg_Suplr_Sbmtd_Chrg
# Tot_Suplr_Srvcs
# Tot_Suplr_Clms
# Tot_Suplrs
# Tot_Rfrg_Prvdrs

# %% [markdown]
# # ***Interpreting Permutation Importances***
#
# The values towards the top are the most important features, and those towards the bottom matter least.
#
# The first number in each row shows how much model performance decreased with a random shuffling (in this case, using "accuracy" as the performance metric).
#
# Like most things in data science, there is some randomness to the exact performance change from a shuffling a column. We measure the amount of randomness in our permutation importance calculation by repeating the process with multiple shuffles. The number after the ± measures how performance varied from one-reshuffling to the next.
#
# You'll occasionally see negative values for permutation importances. In those cases, the predictions on the shuffled (or noisy) data happened to be more accurate than the real data. This happens when the feature didn't matter (should have had an importance close to 0), but random chance caused the predictions on shuffled data to be more accurate. This is more common with small datasets, like the one in this example, because there is more room for luck/chance.
#
# In our example, the most important feature was Goals scored. That seems sensible. Soccer fans may have some intuition about whether the orderings of other variables are surprising or not.

# %% [markdown]
# ***Question 5:***
# Which independent variables have missing data? How much?
#
# A: No independent variables have any missing data or zeros.

# %% [markdown]
# ***Question 6:***
# Do the training and test sets have the same data?
#
# A: Yes, most of the data are same in test, train and validation data set except the data points in training set are more and few boundary values are not included in train and validation data set.

# %% [markdown]
# ***Question 7:***
# Are the predictor variables independent of all the other predictor variables?
#
# There is multi - collinearity among lot of the independent variable which is shown by the correlation table and pairplot map

# %% [markdown]
# ***Question 8:***
# Which predictor variables are the most important?
#
# Avg_Suplr_Mdcr_Stdzd_Amount ,
# Avg_Suplr_Mdcr_Alowd_Amt ,
# Avg_Suplr_Sbmtd_Chrg ,
# Tot_Suplr_Srvcs ,
# Tot_Suplr_Clms ,
# Tot_Suplrs ,
# Tot_Rfrg_Prvdrs

# %% [markdown]
# ***Question 9:***

# %% [markdown]
# ***Question 10:***
#
# Looking at the Q-Q plots, it appears that all independednt variables are roughly following bimodal or multinodal distribution
#
# Rfrg_Prvdr_Geo_Lvl
# Rfrg_Prvdr_Geo_Desc
# BETOS_Lvl
# BETOS_Cd
# BETOS_Desc
# HCPCS_Cd
# HCPCS_Desc
# Suplr_Rentl_Ind
# are all categorical values

# %% [markdown]
# Question 11: Remove outliers and keep outliers (does if have an effect of the final predictive model)?
#
# Yes 'Tot_Suplrs','Tot_Suplr_Clms','Tot_Suplr_Srvcs' values had many outliers and they were normalized and it had a positive effect on the model.

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %% [markdown]
# True Positives (TP): 9
# True Negatives (TN): 781
# False Positives (FP): 99
# False Negatives (FN): 111
# From these values, you can calculate various performance metrics:
#
# Accuracy: (9 + 781) / (9 + 781 + 99 + 111)
# Precision: 9 / (9 + 99)
# Recall: 9 / (9 + 111)
# Specificity: 781 / (781 + 99)
# F1 Score: 2 * (Precision * Recall) / (Precision + Recall)
# These metrics provide insights into the model's performance, such as its ability to correctly identify positive and negative instances, as well as the overall accuracy of predictions.

# %%
from sklearn.metrics import accuracy_score

# define true labels
true_labels = ["a", "c", "b", "a"]

# define corresponding predicted labels
pred_labels = ["c", "c", "b", "a"]

# find accuracy scores
accuracy = accuracy_score(true_labels, pred_labels)
print("Prediction's accuracy is : ", accuracy)

# find number of accurate predictions
accurate_predictions = accuracy_score(true_labels, pred_labels, normalize=False)
print("Total Number of prediction that are accuruate: ", accurate_predictions)
# Out:
# Prediction's accuracy is :  0.75
# Total Number of prediction that are accuruate:  3

# %%
# 10% data randomly delete
import numpy as np

# get dimensions of df
nrows, ncols = len(data_norm.index), 23

volume = nrows * ncols                    # total number of entries in df
volume_to_be_nan = int(volume * 0.1)      # number of entries to turn to NaN (10 %)

# randomly generate index locations for the new NaNs
indices = np.random.randint(volume, size=volume_to_be_nan)
row_indices = indices % nrows
col_indices = (indices / nrows).astype(int)

# assign NaN to each of the indices in df
for ri, ci in zip(row_indices, col_indices):
  data_norm.iloc[ri, ci] = np.nan
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-6b818cf78c2b> in <cell line: 16>()
#      15 # assign NaN to each of the indices in df
#      16 for ri, ci in zip(row_indices, col_indices):
# ---> 17   data_norm.iloc[ri, ci] = np.nan
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     813             key = com.apply_if_callable(key, self.obj)
#     814         indexer = self._get_setitem_indexer(key)
# --> 815         self._has_valid_setitem_indexer(key)
#     816
#     817         iloc = self if self.name == "iloc" else self.obj.iloc
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1516             elif is_integer(i):
#    1517                 if i >= len(ax):
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values= np.NAN, strategy= 'mean', fill_value=None, verbose=0, copy=True)

imputer = imputer.fit(data_norm)

imputed_data = imputer.transform(data_norm.values)

print(imputed_data)
# Out:
# [[ 6.  4.  8. ...  1.  1.  1.]
#  [ 5.  4.  8. ...  2.  1.  1.]
#  [ 3.  2.  5. ...  1.  1.  1.]
#  ...
#  [ 4.  3.  4. ...  2.  1.  1.]
#  [ 8.  6. 11. ...  1.  1.  1.]
#  [ 3.  1.  5. ...  3.  3.  3.]]
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:382: FutureWarning: The 'verbose' parameter was deprecated in version 1.1 and will be removed in 1.3. A warning will always be raised upon the removal of empty columns in the future version.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Assuming 'numeric_data' is your DataFrame with numeric columns
# Replace this with your actual DataFrame name

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the numeric data using Min-Max Scaling

normalized_data = scaler.fit_transform(numeric_data)

# Create a new DataFrame with the normalized values
normalized_df = pd.DataFrame(normalized_data, columns=numeric_data.columns)

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values= np.NAN, strategy= 'mean', fill_value=None, verbose=0, copy=True)

imputer = imputer.fit(data_norm)

imputed_data = imputer.transform(data_norm.values)

print(imputed_data)
# Out:
# [[ 6.  4.  8. ...  1.  1.  1.]
#  [ 5.  4.  8. ...  2.  1.  1.]
#  [ 3.  2.  5. ...  1.  1.  1.]
#  ...
#  [ 4.  3.  4. ...  2.  1.  1.]
#  [ 8.  6. 11. ...  1.  1.  1.]
#  [ 3.  1.  5. ...  3.  3.  3.]]
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:382: FutureWarning: The 'verbose' parameter was deprecated in version 1.1 and will be removed in 1.3. A warning will always be raised upon the removal of empty columns in the future version.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('/content/healthsupplier_2017.csv')
df.dtypes
# Out:
# <ipython-input-48-4657841c9fb7>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/healthsupplier_2017.csv')
# Rfrg_Prvdr_Geo_Lvl           object
# Rfrg_Prvdr_Geo_Cd            object
# Rfrg_Prvdr_Geo_Desc          object
# BETOS_Lvl                    object
# BETOS_Cd                     object
# BETOS_Desc                   object
# HCPCS_Cd                     object
# HCPCS_Desc                   object
# Suplr_Rentl_Ind              object
# Tot_Rfrg_Prvdrs               int64
# Tot_Suplrs                    int64
# Tot_Suplr_Benes             float64
# Tot_Suplr_Clms                int64
# Tot_Suplr_Srvcs               int64
# Avg_Suplr_Sbmtd_Chrg        float64
# Avg_Suplr_Mdcr_Alowd_Amt    float64
# Avg_Suplr_Mdcr_Pymt_Amt     float64
# Avg_Suplr_Mdcr_Stdzd_Amt    float64
# dtype: object

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Load the dataset (replace 'your_dataset.csv' with the actual file name)
df = data_norm

# Identify and separate categorical columns
categorical_columns = ['Rfrg_Prvdr_Geo_Lvl','Rfrg_Prvdr_Geo_Desc','BETOS_Lvl','BETOS_Cd','BETOS_Desc','HCPCS_Cd','HCPCS_Desc','Suplr_Rentl_Ind']

numerical_columns = df.select_dtypes(include=['number']).columns

# Remove 1%, 5%, and 10% of your data randomly
np.random.seed(42)  # Set seed for reproducibility
missing_percentages = [0.01, 0.05, 0.1]

for percentage in missing_percentages:
    mask = np.random.rand(*df.shape) < 1 - percentage
    df_missing = df.copy()
    df_missing[mask] = np.nan

    # Separate numerical and categorical columns
    df_missing_numerical = df_missing[numerical_columns]
    df_missing_categorical = pd.get_dummies(df_missing[categorical_columns], columns=categorical_columns)

    # Concatenate numerical and one-hot encoded categorical columns
    df_missing_encoded = pd.concat([df_missing_numerical, df_missing_categorical], axis=1)

    # Impute the missing values using different methods
    imputation_methods = ['mean', 'iterative', 'knn']
    for method in imputation_methods:
        if method == 'mean':
            imputer = SimpleImputer(strategy='mean')
        elif method == 'iterative':
            imputer = IterativeImputer(max_iter=10, random_state=42)
        elif method == 'knn':
            imputer = KNNImputer(n_neighbors=5)

        df_imputed_encoded = pd.DataFrame(imputer.fit_transform(df_missing_encoded), columns=df_missing_encoded.columns)

        # Evaluate the imputation quality using a regression model
        X_train, X_test, y_train, y_test = train_test_split(
            df_imputed_encoded.drop(columns='Avg_Suplr_Mdcr_Pymt_Amt'), df_imputed_encoded['Avg_Suplr_Mdcr_Pymt_Amt'], test_size=0.2, random_state=42
        )

        model = LinearRegression()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Calculate the residuals and error metrics
        residuals = y_test - y_pred
        mse = mean_squared_error(y_test, y_pred)
        percent_error = np.mean(np.abs(residuals) / np.abs(y_test)) * 100

        print(f"Missing Percentage: {percentage * 100}% | Imputation Method: {method}")
        print(f"Mean Squared Error: {mse}")
        print(f"Percent Error on Residuals: {percent_error}%")
        print('-' * 50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-fccd48481be5> in <cell line: 23>()
#      28     # Separate numerical and categorical columns
#      29     df_missing_numerical = df_missing[numerical_columns]
# ---> 30     df_missing_categorical = pd.get_dummies(df_missing[categorical_columns], columns=categorical_columns)
#      31
#      32     # Concatenate numerical and one-hot encoded categorical columns
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...
